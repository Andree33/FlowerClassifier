# %%
import seaborn as sns
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
df = sns.load_dataset('iris')
df.head()
# print(sns.get_dataset_names())
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
species = df['species'].unique()
species
# Out:
# <StringArray>
# ['setosa', 'versicolor', 'virginica']
# Length: 3, dtype: str

# %%
df[df['species'] == 'setosa'].head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(df[df['species'] == 'setosa'])

# %%
sns.boxplot(x = "sepal_length", y = "species", data = df, label="sl")
sns.boxplot(x = "sepal_width", y = "species", data = df, label="sw", color="C5")
sns.boxplot(x = "petal_length", y = "species", data = df, label="pl")
sns.boxplot(x = "petal_width", y = "species", data = df, label="pd")
plt.legend()
plt.show()

# Transformar os dados para o formato "long-form"
# Isso coloca todas as métricas numa coluna e os valores noutra
df_melted = df.melt(id_vars='species', var_name='Metric', value_name='Value')

# Criar a matriz de boxplots
g = sns.FacetGrid(df_melted, col="Metric", col_wrap=2, sharey=False, height=4)
g.map(sns.boxplot, "species", "Value", order=["setosa", "versicolor", "virginica"])

plt.show()


# g = sns.FacetGrid(df_long, col="Metric", height=4, aspect=0.8)
# g.map(sns.boxplot, "species", "cm", order=["setosa", "versicolor", "virginica"])

# %%
X = df.drop('species', axis=1)
Y = df['species']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25 random_state = 12, stratify=y)
# Out:
#   Cell In[8], line 1
#     X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.25 random_state = 12, stratify=y)
#                                                                         ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %%
model = RandomForestClassifier(random_state=12)

# %%
model.fit(X_train, Y_train)
# Out:
# RandomForestClassifier(random_state=12)

# %%
Y_pred = model.predict(X_test)

# %%
accuracy_score(Y_pred, Y_test)
# Out:
# 0.9736842105263158
